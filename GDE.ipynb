# %% [markdown]
# ### Kaggle API

# %% [markdown]
# ###### Excecution Steps:
#
# 1. Install Kaggle_API
# 2. Set Kaggle API Token
# 3. Search for Dataset
# 4. Download Dataset

# %% [markdown]
# Set Kaggle API Token
# * Download *kaggle.json* file from Kaggle
# * Create *.kaggle* folder in ROOT directory
# * Paste *kaggle.json* to ROOT directory

# %% [markdown]
# ### Search Kaggle

# %%
# !kaggle datasets list -s "Global Disaster Events"
# Out:
# ref                                                             title                                                     size  lastUpdated                 downloadCount  voteCount  usabilityRating
# --------------------------------------------------------------  --------------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# zubairdhuddi/global-daset                                       Global Disaster Response Analysis (2018–2024)          1737432  2025-11-11 10:19:57                  1452         30  1.0
# elvinrustam/global-disaster-events-20002025                     Global Disaster Events (2000–2025)                     2295712  2025-09-02 11:03:54.873000            435          6  1.0
# nasa/landslide-events                                           Landslides After Rainfall, 2007-2016                    130677  2017-01-19 15:58:33.987000          14383        105  0.8235294
# shreyanshdangi/global-natural-calamities-dataset                Global Natural Disasters Dataset                        355020  2025-07-30 11:53:58                   521         83  1.0
# emirhanakku/disaster-and-emergency-response-dataset-20182024    Disaster & Emergency Response Dataset (2018–2024)      1737424  2025-11-10 19:01:20.837000           1145         48  1.0
# shreyasur965/recent-earthquakes                                 Global Earthquake Data                                  219182  2024-09-19 16:18:55.843000           5559         45  1.0
# jahaidulislam/significant-earthquake-dataset-1900-2023          Significant Earthquake Dataset 1900-2023               1626294  2023-02-18 09:34:20.003000           2655         44  1.0
# tr1gg3rtrash/global-disaster-risk-index-time-series-dataset     World Disaster Risk Dataset                              41821  2022-09-07 06:31:16                  3697         67  1.0
# adilshamim8/temperature                                         Global Environmental Trends 2000-2024                     3397  2025-04-24 16:19:09                  2757         37  1.0
# vivektiwari020801/real-time-lightning-strikes                   Real-time Lightning Strikes                           42881439  2025-12-07 12:56:52.277000            711         22  0.9411765
# deffro/the-climate-change-twitter-dataset                       The Climate Change Twitter Dataset                   428878019  2022-05-26 13:11:05.953000           2852         40  0.9705882
# sathyanarayanrao89/global-landslide-catalog                     Global Landslide Catalog                               3036224  2022-07-06 17:32:52.047000            782         21  0.8235294
# kazushiadachi/global-landslide-data                             Global Landslide Data                                  3036232  2022-03-21 00:45:33.567000           1373         11  0.7647059
# shuvokumarbasak4004/nasa-global-landslide-catalog-dataset       NASA Global Landslide Catalog Dataset                  3036234  2025-08-05 04:20:57.597000            144         16  0.64705884
# thedevastator/mining-disaster-related-insights-from-social-med   Social Media Disaster-Related Discussions              810334  2022-12-14 03:55:04                   319          5  1.0
# shubamsumbria/decadal-avg-natural-disasters-data-1900-2010      Decadal Avg. Natural Disasters Data [ 1900 - 2010]      205954  2022-02-25 06:59:08.607000            261         13  0.88235295
# patricklford/mass-disasters-in-vietnam-from-1900-to-2024        Mass disasters in Vietnam from 1953 to 2024              24270  2025-06-12 09:56:17.603000            240          4  1.0
# orvile/the-climate-change-twitter-dataset                       The Climate Change Twitter Dataset                   428878071  2025-04-22 20:14:28                   233         14  0.9411765
# vidiqlogy/global-landslide-catalog                              Global Landslide Catalog                                892894  2022-04-16 08:57:36.813000             77          5  0.4117647
# syedahnafraza/global-earthquake-and-aftershock-data-january-23  Global Earthquake and Aftershock Data (January 23)       81387  2024-08-18 20:37:37.283000             78          2  0.88235295

# %% [markdown]
# ### Download the Dataset

# %%
# !kaggle datasets download -d "elvinrustam/global-disaster-events-20002025"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/elvinrustam/global-disaster-events-20002025
# License(s): CC0-1.0
# global-disaster-events-20002025.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ### Unzip and Read the Data

# %% [markdown]
# Unzip the ".zip" file using zipfile library

# %%
import zipfile
import os

# %%
with zipfile.ZipFile("global-disaster-events-20002025.zip", "r") as file:
    file.extractall("Global Disaster Events")

# %%
os.listdir("Global Disaster Events")
# Out:
# ['.ipynb_checkpoints', 'Clean', 'gde-preclean.csv', 'Unclean']

# %%
# os.listdir("Global Disaster Events/Unclean")

# %% [markdown]
# #### `Wrangle` and Read Data

# %%
import warnings

import pandas as pd

warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
def wrangle(filepath):
    # Read CSV file into dataframe
    df = pd.read_csv(filepath)
    return df

# %%
Drought = wrangle("Unclean/Drought.csv")
print("Drought datashape:", Drought.shape)
Drought.head(2)
# Out:
# Drought datashape: (1780, 22)
#         coordinates                                               name  \
# 0  [11.087, 53.882]  Drought in Germany, Denmark, France, Latvia, P...
# 1  [11.087, 53.882]  Drought in Germany, Denmark, France, Latvia, P...
#
#                                          description  \
# 0  Drought in Germany, Denmark, France, Latvia, P...
# 1  Drought in Germany, Denmark, France, Latvia, P...
#
#                                      htmldescription alertlevel  alertscore  \
# 0  Green Drought in Germany, Denmark, France, Lat...      Green           1
# 1  Green Drought in Germany, Denmark, France, Lat...      Green           1
#
#   episodealertlevel  episodealertscore  \
# 0             Green               0.25
# 1             Green               0.25
#
#                                             country             fromdate  ...  \
# 0  Germany, Denmark, France, Latvia, Poland, Sweden  2017-07-21T00:00:00  ...
# 1  Germany, Denmark, France, Latvia, Poland, Sweden  2017-07-21T00:00:00  ...
#
#                                         severitytext  source iso3 eventtype  \
# 0  Minor impact for agricultural drought in 80936...     GDO  DEU        DR
# 1  Minor impact for agricultural drought in 80936...     GDO  DEU        DR
#
#      GDACS ID                           Name  \
# 0  DR 1012168   Central Northern Europe-2018
# 1  DR 1012168   Central Northern Europe-2018
#
#                                           Countries        Start Date  \
# 0  Germany, Denmark, France, Latvia, Poland, Sweden  End of Jul 2017
# 1  Germany, Denmark, France, Latvia, Poland, Sweden  End of Jul 2017
#
#                     Duration  \
# 0  569 days (at 18 Feb 2019)
# 1  569 days (at 18 Feb 2019)
#
#                                               Impact
# 0  Minor impact for agricultural drought in 80936...
# 1  Minor impact for agricultural drought in 80936...
#
# [2 rows x 22 columns]

# %%
# Drought.info()

# %% [markdown]
# ## Clean `Drought Data`

# %%
# Split coordinates into longitudes and latitudes
Drought[['longitude', 'latitude']] = Drought['coordinates'].str.strip("[]").str.split(",", expand=True)

# %%
from country_converter import CountryConverter

cc = CountryConverter()
Drought["Country"] = cc.convert(Drought["iso3"], to = "name_short")

for time in ["fromdate", "todate"]:
    Drought[time] = pd.to_datetime(Drought[time]).dt.tz_localize('UTC').dt.tz_convert("Africa/Nairobi")

# %%
#Rename column "severity" to "severity(km2)" in Drought dataframe
Drought["severity(km2)"] = Drought["severity"].astype(int)

# Extract the number of days the event lasted
Drought["Duration(days)"] = Drought["Duration"].str.split().str[0].astype(int)

# %%
Drought_data = Drought.copy()
DROUGHT = Drought_data[['alertlevel','alertscore', 'fromdate', 'todate', 'severity(km2)', 'iso3', 'eventtype','Impact', 'longitude', 'latitude', 'Country', 'Duration(days)']]

# %%
# DROUGHT.info()

# %% [markdown]
# ## Clean `Earthquake Data`

# %%
Earthquake = wrangle("Unclean/Earthquake.csv")
print("Earthquake datashape:", Earthquake.shape)
Earthquake.head(2)
# Out:
# Earthquake datashape: (20296, 20)
#         coordinates                       name                description  \
# 0      [70.4, 36.2]  Earthquake in Afghanistan  Earthquake in Afghanistan
# 1  [58.175, 35.217]         Earthquake in Iran         Earthquake in Iran
#
#                                      htmldescription alertlevel  alertscore  \
# 0  Red M 6.4 Earthquake in Afghanistan at: 19 Jan...        Red           3
# 1  Green M 4.9 Earthquake in Iran at: 14 Feb 2000...      Green           1
#
#   episodealertlevel  episodealertscore      country             fromdate  \
# 0               Red                3.0  Afghanistan  2000-01-19T00:00:00
# 1             Green                0.5         Iran  2000-02-14T00:00:00
#
#                 todate  severity                  severitytext source iso3  \
# 0  2000-01-19T00:00:00       6.4  magnitude 6.4M and depth 0km   NEIC  AFG
# 1  2000-02-14T00:00:00       4.9  magnitude 4.9M and depth 0km   NEIC  IRN
#
#   eventtype Earthquake Magnitude Depth          Exposed Population Capacity
# 0        EQ                 6.4M  0 Km  460000 people within 100km      NaN
# 1        EQ                 4.9M  0 Km  440000 people within 100km      NaN

# %%
# Print info
Earthquake.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20296 entries, 0 to 20295
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   coordinates           20296 non-null  object
#  1   name                  20296 non-null  object
#  2   description           20296 non-null  object
#  3   htmldescription       20296 non-null  object
#  4   alertlevel            20296 non-null  object
#  5   alertscore            20296 non-null  int64
#  6   episodealertlevel     20296 non-null  object
#  7   episodealertscore     20296 non-null  float64
#  8   country               18490 non-null  object
#  9   fromdate              20296 non-null  object
#  10  todate                20296 non-null  object
#  11  severity              20296 non-null  float64
#  12  severitytext          20296 non-null  object
#  13  source                20296 non-null  object
#  14  iso3                  19215 non-null  object
#  15  eventtype             20296 non-null  object
#  16  Earthquake Magnitude  20296 non-null  object
#  17  Depth                 20296 non-null  object
#  18  Exposed Population    19205 non-null  object
#  19  Capacity              4356 non-null   object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 3.1+ MB

# %%
Earthquake[['longitude', 'latitude']] = Earthquake['coordinates'].str.strip("[]").str.split(",", expand=True)

# %%
# Remove "NaN" values 
Earthquake.dropna(inplace= True)

# %%
Earthquake["iso3"] = Earthquake["iso3"].replace("ROM", "ROU")

# %%
Earthquake["Country"] = cc.convert(Earthquake["iso3"], to = "name_short")

for time in ["fromdate", "todate"]:
    Earthquake[time] = pd.to_datetime(Earthquake[time]).dt.tz_localize('UTC').dt.tz_convert("Africa/Nairobi")

# %%
# Remove the 'M' and convert to float
Earthquake["Magnitude(M)"] = Earthquake["Earthquake Magnitude"].str.replace("M", "", regex=False).astype(float)

# Depth of earthquake in km
Earthquake["Depth(km)"] = Earthquake["Depth"].str.replace(r'[^\d.]', '', regex=True)

# %%
Earthquake_data = Earthquake.copy()
EARTHQUAKE = Earthquake_data[['alertlevel','alertscore', 'fromdate', 'todate', 'Magnitude(M)', 
  'iso3', 'eventtype','Depth(km)', 'longitude', 'latitude', 'Country']]

# %%
# EARTHQUAKE.info()

# %% [markdown]
# ## Clean `Eruption Data`

# %%
Eruption = wrangle("Unclean/Eruption.csv")
print("Eruption datashape:", Eruption.shape)
Eruption.head(2)
# Out:
# Eruption datashape: (186, 22)
#             coordinates                              name  \
# 0  [-130.55, 56.583333]  Eruption  Iskut-Unuk River Cones
# 1   [-72.966666, -45.9]           Eruption  Hudson, Cerro
#
#                         description  \
# 0  Eruption  Iskut-Unuk River Cones
# 1           Eruption  Hudson, Cerro
#
#                                      htmldescription alertlevel  alertscore  \
# 0  Green Eruption Iskut-Unuk River Cones in Canad...      Green           1
# 1  Green Eruption Hudson, Cerro in Chile-S at: 28...      Green           1
#
#   episodealertlevel  episodealertscore  country             fromdate  ...  \
# 0             Green                0.0   Canada  2011-09-20T18:00:00  ...
# 1             Green                0.0  Chile-S  2011-10-28T09:48:00  ...
#
#   severitytext        source  iso3 eventtype GDACS ID  \
# 0          NaN      MONTREAL              VO   VO 360
# 1          NaN  BUENOS AIRES              VO   VO 484
#
#                         Name Exposed Population 30km Exposed Population 100km  \
# 0  Iskut-Unuk River Cones ()                     NaN       No people affected
# 1           Hudson, Cerro ()                     NaN       No people affected
#
#   Max Volc. Explosivity Index VEI Population Exposure Index PEI
# 0                             NaN                           NaN
# 1                             NaN                           NaN
#
# [2 rows x 22 columns]

# %%
# Eruption.info()

# %%
Eruption[['longitude', 'latitude']] = Eruption['coordinates'].str.strip("[]").str.split(",", expand=True)

# %%
# Remove "NaN" values row-wise and column-wise
Eruption = Eruption.dropna(axis=1, how='all').dropna(axis=0, how='any').reset_index(drop=True)

# %%
# Eruption.info()

# %%
Eruption.rename(columns={"Max Volc. Explosivity Index VEI": "Severity(VEI)"}, inplace=True)

Eruption["iso3"] = Eruption["iso3"].replace("ROM", "ROU")

# %%
Eruption["Country"] = cc.convert(Eruption["iso3"], to = "name_short")

for time in ["fromdate", "todate"]:
    Eruption[time] = pd.to_datetime(Eruption[time]).dt.tz_localize('UTC').dt.tz_convert("Africa/Nairobi")

# %%
Eruption_data = Eruption.copy()
ERUPTION = Eruption_data[['alertlevel','alertscore', 'fromdate', 'todate', 'Severity(VEI)', 
  'iso3', 'eventtype', 'longitude', 'latitude', 'Country']]

# %%
# ERUPTION.info()

# %% [markdown]
# ## Clean `Flood Data`

# %%
Flood = wrangle("Unclean/Flood.csv")
print("Flood datashape:", Flood.shape)
Flood.head(2)
# Out:
# Flood datashape: (2441, 19)
#          coordinates                   name            description  \
# 0  [31.712, -27.822]    Flood in Mozambique    Flood in Mozambique
# 1     [126.1, 7.199]  Flood in Philippines   Flood in Philippines
#
#                                      htmldescription alertlevel  alertscore  \
# 0  ORANGE Flood in Mozambique from: 26 Jan 2000 0...     ORANGE           2
# 1  GREEN Flood in Philippines from: 28 Jan 2000 0...      GREEN           1
#
#   episodealertlevel  episodealertscore       country             fromdate  \
# 0            ORANGE                2.0    Mozambique  2000-01-26T00:00:00
# 1             GREEN                1.0  Philippines   2000-01-28T00:00:00
#
#                 todate  severity    severitytext source iso3 eventtype  Death  \
# 0  2000-03-27T23:59:59      7.74  Magnitude 7.74    DFO  MOZ        FL  929.0
# 1  2000-02-01T23:59:59      4.92  Magnitude 4.92    DFO  PHL        FL   23.0
#
#   Displaced GDACS_ID
# 0    733000  FL 1583
# 1     20000  FL 1584

# %%
Flood.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2441 entries, 0 to 2440
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   coordinates        2441 non-null   object
#  1   name               2441 non-null   object
#  2   description        2441 non-null   object
#  3   htmldescription    2441 non-null   object
#  4   alertlevel         2441 non-null   object
#  5   alertscore         2441 non-null   int64
#  6   episodealertlevel  2441 non-null   object
#  7   episodealertscore  2438 non-null   float64
#  8   country            2441 non-null   object
#  9   fromdate           2441 non-null   object
#  10  todate             2441 non-null   object
#  11  severity           2441 non-null   float64
#  12  severitytext       2441 non-null   object
#  13  source             2441 non-null   object
#  14  iso3               2330 non-null   object
#  15  eventtype          2441 non-null   object
#  16  Death              2440 non-null   float64
#  17  Displaced          2440 non-null   object
#  18  GDACS_ID           2441 non-null   object
# dtypes: float64(3), int64(1), object(15)
# memory usage: 362.5+ KB

# %%
Flood[['longitude', 'latitude']] = Flood['coordinates'].str.strip("[]").str.split(",", expand=True)

# %%
# Remove "NaN" values 
Flood.dropna(inplace= True)

# %%
Flood["iso3"] = Flood["iso3"].replace("ROM", "ROU")

# %%
mapping = {
    "ANG": "AGO",  # Angola
    "RWD": "RWA",  # Rwanda
    "ALG": "DZA",  # Algeria
}

Flood["iso3"] = Flood["iso3"].replace(mapping)

# Convert
Flood["Country"] = cc.convert(Flood["iso3"], to="name_short")
# Out:
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
# SUA not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3

# %%
for time in ["fromdate", "todate"]:
    Flood[time] = pd.to_datetime(Flood[time]).dt.tz_localize('UTC').dt.tz_convert("Africa/Nairobi")

# %%
# Rename severity of the floods in relation to height
Flood.rename(columns={"severity": "Severity(metres)"}, inplace=True)

# Fill NaN values in Deaths with zero
Flood['Deaths'] = Flood['Death'].fillna(0).astype(int)

# %%
Flood_data = Flood.copy()

FLOOD = Flood_data[['alertlevel','alertscore', 'fromdate', 'todate', 'Severity(metres)', 
  'iso3', 'eventtype','Deaths','Displaced', 'longitude', 'latitude', 'Country']]

# %%
# FLOOD.info()

# %% [markdown]
# ## Clean `ForestFires Data`

# %%
ForestFires = wrangle("Unclean/Forest Fires.csv")
print("ForestFires datashape:", ForestFires.shape)
ForestFires.head(2)
# Out:
# ForestFires datashape: (3055, 22)
#                                coordinates                   name  \
# 0  [105.65993703583405, 17.33516236486571]   Forest fires in Laos
# 1  [85.87540845200718, 22.856787081945416]  Forest fires in India
#
#              description                                    htmldescription  \
# 0   Forest fires in Laos  Green Forest fires in Laos from: 23 Feb 2021 t...
# 1  Forest fires in India  Green Forest fires in India from: 25 Feb 2021 ...
#
#   alertlevel  alertscore episodealertlevel  episodealertscore country  \
# 0      Green           1             GREEN                1.0    Laos
# 1      Green           1             GREEN                1.0   India
#
#               fromdate  ...                            severitytext  source  \
# 0  2021-02-23T00:00:00  ...  Green impact for forestfire in 5070 ha    GWIS
# 1  2021-02-25T00:00:00  ...  Green impact for forestfire in 9866 ha    GWIS
#
#   iso3 eventtype    GDACS ID           People affected Countries  \
# 0  LAO        WF  WF 1000144      0 in the burned area      Laos
# 1  IND        WF  WF 1000128  35445 in the burned area     India
#
#    Start Date - Last detection Duration (days) Burned area
# 0  23 Feb 2021  - 23 Mar 2021               28     5070 ha
# 1  25 Feb 2021  - 11 Mar 2021               14     9866 ha
#
# [2 rows x 22 columns]

# %%
# ForestFires.info()

# %%
ForestFires[['longitude', 'latitude']] = ForestFires['coordinates'].str.strip("[]").str.split(",", expand=True)

# %%
ForestFires["Country"] = cc.convert(ForestFires["iso3"], to = "name_short")

for time in ["fromdate", "todate"]:
    ForestFires[time] = pd.to_datetime(ForestFires[time]).dt.tz_localize('UTC').dt.tz_convert("Africa/Nairobi")

# %%
# Rename severity of the floods in relation to height
ForestFires.rename(columns={"severity": "Severity(ha)"}, inplace=True)

# Extract number of people affected
ForestFires["People affected"] = ForestFires["People affected"].str.extract(r'(\d+)').astype(int)

# %%
ForestFires_data = ForestFires.copy()

FORESTFIRES = ForestFires_data[['alertlevel','alertscore', 'fromdate', 'todate', 'Severity(ha)', 
  'iso3', 'eventtype','People affected', 'Duration (days)','longitude', 'latitude', 'Country']]

# %%
# FORESTFIRES.info()

# %% [markdown]
# ## Clean `TropicalCyclone Data`

# %%
TropicalCyclone = wrangle("Unclean/Tropical Cyclone.csv")
print("TropicalCyclone datashape:", TropicalCyclone.shape)
TropicalCyclone.head(2)
# Out:
# TropicalCyclone datashape: (405, 23)
#                             coordinates                        name  \
# 0                  [97.5, 18.299999237]  Tropical Cyclone NARGIS-08
# 1  [136.600000000219, 34.3999999997814]  Tropical Cyclone SONGDA-11
#
#                   description  \
# 0  Tropical Cyclone NARGIS-08
# 1  Tropical Cyclone SONGDA-11
#
#                                      htmldescription alertlevel  alertscore  \
# 0  Red Tropical Cyclone NARGIS-08 off-shore from:...        Red           3
# 1  Orange Tropical Cyclone SONGDA-11 in Japan fro...     Orange           2
#
#   episodealertlevel  episodealertscore country             fromdate  ...  \
# 0             Green                1.0     NaN  2008-04-28T06:00:00  ...
# 1             Green                1.0   Japan  2011-05-22T00:00:00  ...
#
#   source  iso3 eventtype  GDACS ID       Name Exposed countries  \
# 0   JTWC              TC  TC 10238  NARGIS-08         Off-shore
# 1    JRC              TC  TC 24054  SONGDA-11             Japan
#
#                    Exposed population      Maximum wind speed  \
# 0  7 million  in Category 1 or higher  74 km/h Tropical storm
# 1  No people  in Category 1 or higher  64 km/h Tropical storm
#
#   Maximum storm surge Vulnerability
# 0                n.a.         -- ()
# 1                n.a.        Low ()
#
# [2 rows x 23 columns]

# %%
# Print info
# TropicalCyclone.info()

# %%
TropicalCyclone[['longitude', 'latitude']] = TropicalCyclone['coordinates'].str.strip("[]").str.split(",", expand=True)

# %%
# Remove "NaN" values 
TropicalCyclone.dropna(inplace= True)

# %%
TropicalCyclone["iso3"] = TropicalCyclone["iso3"].replace("ROM", "ROU")

# %%
TropicalCyclone["Country"] = cc.convert(TropicalCyclone["iso3"], to = "name_short")

for time in ["fromdate", "todate"]:
    TropicalCyclone[time] = pd.to_datetime(TropicalCyclone[time]).dt.tz_localize('UTC').dt.tz_convert("Africa/Nairobi")
# Out:
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3
#     not found in ISO3

# %%
TropicalCyclone["Max. Windspeed"] = TropicalCyclone["Maximum wind speed"].str.extract(r'(\d+)').astype(int)

# %%
TropicalCyclone_data = TropicalCyclone.copy()

TROPICALCYCLONE = TropicalCyclone_data[['alertlevel','alertscore', 'fromdate', 'todate', 
  'iso3', 'eventtype', 'Max. Windspeed','longitude', 'latitude', 'Country']]

# %%
# TROPICALCYCLONE.info()

# %% [markdown]
# ### Concatenate Dataframes

# %%
# Concatenate dataframes
df =  pd.concat([DROUGHT,EARTHQUAKE,ERUPTION,FLOOD,FORESTFIRES,TROPICALCYCLONE])

# %%
# Print object type, shape, and head
print("df type:", type(df))
print("df shape:", df.shape)
df.head(3)
# Out:
# df type: <class 'pandas.core.frame.DataFrame'>
# df shape: (11221, 22)
#   alertlevel  alertscore                  fromdate                    todate  \
# 0      Green           1 2017-07-21 03:00:00+03:00 2019-02-09 18:07:00+03:00
# 1      Green           1 2017-07-21 03:00:00+03:00 2019-02-09 18:07:00+03:00
# 2      Green           1 2017-07-21 03:00:00+03:00 2019-02-09 18:07:00+03:00
#
#    severity(km2) iso3 eventtype  \
# 0        80936.0  DEU        DR
# 1        80936.0  DEU        DR
# 2        80936.0  DEU        DR
#
#                                               Impact longitude latitude  ...  \
# 0  Minor impact for agricultural drought in 80936...    11.087   53.882  ...
# 1  Minor impact for agricultural drought in 80936...    11.087   53.882  ...
# 2  Minor impact for agricultural drought in 80936...    11.087   53.882  ...
#
#   Magnitude(M)  Depth(km)  Severity(VEI) Severity(metres)  Deaths  Displaced  \
# 0          NaN        NaN            NaN              NaN     NaN        NaN
# 1          NaN        NaN            NaN              NaN     NaN        NaN
# 2          NaN        NaN            NaN              NaN     NaN        NaN
#
#    Severity(ha) People affected  Duration (days)  Max. Windspeed
# 0           NaN             NaN              NaN             NaN
# 1           NaN             NaN              NaN             NaN
# 2           NaN             NaN              NaN             NaN
#
# [3 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11221 entries, 0 to 404
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   alertlevel        11221 non-null  object
#  1   alertscore        11221 non-null  int64
#  2   fromdate          11221 non-null  datetime64[ns, Africa/Nairobi]
#  3   todate            11221 non-null  datetime64[ns, Africa/Nairobi]
#  4   severity(km2)     1780 non-null   float64
#  5   iso3              11221 non-null  object
#  6   eventtype         11221 non-null  object
#  7   Impact            1780 non-null   object
#  8   longitude         11221 non-null  object
#  9   latitude          11221 non-null  object
#  10  Country           11221 non-null  object
#  11  Duration(days)    1780 non-null   float64
#  12  Magnitude(M)      3669 non-null   float64
#  13  Depth(km)         3669 non-null   object
#  14  Severity(VEI)     167 non-null    float64
#  15  Severity(metres)  2326 non-null   float64
#  16  Deaths            2326 non-null   float64
#  17  Displaced         2326 non-null   object
#  18  Severity(ha)      3055 non-null   float64
#  19  People affected   3055 non-null   float64
#  20  Duration (days)   3055 non-null   float64
#  21  Max. Windspeed    224 non-null    float64
# dtypes: datetime64[ns, Africa/Nairobi](2), float64(10), int64(1), object(9)
# memory usage: 2.0+ MB

# %%
df.columns
# Out:
# Index(['alertlevel', 'alertscore', 'fromdate', 'todate', 'severity(km2)',
#        'iso3', 'eventtype', 'Impact', 'longitude', 'latitude', 'Country',
#        'Duration(days)', 'Magnitude(M)', 'Depth(km)', 'Severity(VEI)',
#        'Severity(metres)', 'Deaths', 'Displaced', 'Severity(ha)',
#        'People affected', 'Duration (days)', 'Max. Windspeed'],
#       dtype='object')

# %% [markdown]
# ## Save `df`

# %%
df.to_csv("Global Disaster Events/gde-preclean.csv", index=False)

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/andrew-kalumba-harris/">Andrew Kalumba</a><br>
# <a href =""> </a>
#
#
# | Date (YYYY-MM-DD) | Prepared By     |
# | ----------------- | --------------  |
# | 2025-12-06        | Author          |
#
#
# ## <h3 align="center"> © Data Science 2025.  <h3/>
